# %% [markdown]
# # Database Admin 101 - Lab
#
# ## Introduction
#
# In this lab, you'll go through the process of designing and creating a database. From there, you'll begin to populate this table with mock data provided to you.
#
# ## Objectives
#
# You will be able to:
#
# * Use knowledge of the structure of databases to create a database and populate it

# %% [markdown]
# ## The Scenario
#
# You are looking to design a database for a school that will house various information from student grades to contact information, class roster lists and attendance. First, think of how you would design such a database. What tables would you include? What columns would each table have? What would be the primary means to join said tables?

# %%
# !ls
# Out:
# CONTRIBUTING.md
# LICENSE.md
# README.md
# contact_list.pickle
# index.ipynb
# school.sqlite

# %% [markdown]
# ## Creating the Database
#
# Now that you've put a little thought into how you might design your database, it's time to go ahead and create it! Start by import the necessary packages. Then, create a database called **school.sqlite**.

# %%
import pandas as pd
import sqlite3

# %%
# Create a connection to the database (or establish a connection if the file already exists)
conn = sqlite3.connect('school.sqlite')

# Create a cursor object to execute SQL commands
cursor = conn.cursor()

# Close the cursor and connection (optional, as Jupyter notebooks automatically close connections when the kernel shuts down)
# cursor.close()
# conn.close()

# %%
# !ls
# Out:
# CONTRIBUTING.md
# LICENSE.md
# README.md
# contact_list.pickle
# index.ipynb
# school.sqlite

# %% [markdown]
# ## Create a Table for Contact Information
#
# Create a table called contactInfo to house contact information for both students and staff. Be sure to include columns for first name, last name, role (student/staff), telephone number, street, city, state, and zipcode. Be sure to also create a primary key for the table.

# %%
# Create the contactInfo table
cursor.execute('''
    CREATE TABLE IF NOT EXISTS contactInfo (
        id INTEGER PRIMARY KEY,
        firstName TEXT,
        lastName TEXT,
        role TEXT,
        telephone TEXT,
        street TEXT,
        city TEXT,
        state TEXT,
        zipcode TEXT
    )
''')

# # Commit the changes and close the cursor and connection
# conn.commit()
# # cursor.close()
# # conn.close()

# %% [markdown]
# ## Populate the Table
#
# Below, code is provided for you in order to load a list of dictionaries. Briefly examine the list. Each dictionary in the list will serve as an entry for your contact info table. Once you've briefly investigated the structure of this data, write a for loop to iterate through the list and create an entry in your table for each person's contact info.

# %%
# Load the list of dictionaries; just run this cell
import pickle

with open('contact_list.pickle', 'rb') as f:
    contacts = pickle.load(f)

# %%
# Iterate over the contact list and populate the contactInfo table
for contact in contacts:
    cursor.execute('''
        INSERT INTO contactInfo (firstName, lastName, role, telephone, street, city, state, zipcode)
        VALUES (?, ?, ?, ?, ?, ?, ?, ?)
    ''', (
        contact.get('firstName'),
        contact.get('lastName'),
        contact.get('role'),
        contact.get('telephone'),
        contact.get('street'),
        contact.get('city'),
        contact.get('state'),
        contact.get('zipcode')
    ))

# # Commit the changes and close the cursor and connection
# conn.commit()
# # cursor.close()
# # conn.close()

# %% [markdown]
# **Query the Table to Ensure it is populated**

# %%
# Create a connection to the database
conn = sqlite3.connect('school.sqlite')

# Query the contactInfo table and retrieve the data as a DataFrame
df = pd.read_sql('SELECT * FROM contactInfo', conn)

# Print the retrieved data
df

# # Close the connection
# conn.close()
# Out:
#     id    firstName  lastName     role telephone                     street  \
# 0    1    Christine    Holden    staff      None         1672 Whitman Court
# 1    2  Christopher    Warren  student      None  1935 University Hill Road
# 2    3        Linda  Jacobson    staff      None        479 Musgrave Street
# 3    4       Andrew     Stepp  student      None  2981 Lamberts Branch Road
# 4    5         Jane     Evans  student      None        1461 Briarhill Lane
# 5    6         Jane     Evans  student      None        1461 Briarhill Lane
# 6    7         Mary    Raines  student      None      3975 Jerry Toth Drive
# 7    8           Ed     Lyman  student      None              3478 Be Sreet
# 8    9    Christine    Holden    staff      None         1672 Whitman Court
# 9   10  Christopher    Warren  student      None  1935 University Hill Road
# 10  11        Linda  Jacobson    staff      None        479 Musgrave Street
# 11  12       Andrew     Stepp  student      None  2981 Lamberts Branch Road
# 12  13         Jane     Evans  student      None        1461 Briarhill Lane
# 13  14         Jane     Evans  student      None        1461 Briarhill Lane
# 14  15         Mary    Raines  student      None      3975 Jerry Toth Drive
# 15  16           Ed     Lyman  student      None              3478 Be Sreet
# 16  17    Christine    Holden    staff      None         1672 Whitman Court
# 17  18  Christopher    Warren  student      None  1935 University Hill Road
# 18  19        Linda  Jacobson    staff      None        479 Musgrave Street
# 19  20       Andrew     Stepp  student      None  2981 Lamberts Branch Road
# 20  21         Jane     Evans  student      None        1461 Briarhill Lane
# 21  22         Jane     Evans  student      None        1461 Briarhill Lane
# 22  23         Mary    Raines  student      None      3975 Jerry Toth Drive
# 23  24           Ed     Lyman  student      None              3478 Be Sreet
# 24  25    Christine    Holden    staff      None         1672 Whitman Court
# 25  26  Christopher    Warren  student      None  1935 University Hill Road
# 26  27        Linda  Jacobson    staff      None        479 Musgrave Street
# 27  28       Andrew     Stepp  student      None  2981 Lamberts Branch Road
# 28  29         Jane     Evans  student      None        1461 Briarhill Lane
# 29  30         Jane     Evans  student      None        1461 Briarhill Lane
# 30  31         Mary    Raines  student      None      3975 Jerry Toth Drive
# 31  32           Ed     Lyman  student      None              3478 Be Sreet
#
#          city state zipcode
# 0    Stamford    CT    None
# 1   Champaign    IL    None
# 2     Atlanta    GA    None
# 3     Hialeah    Fl    None
# 4     Abilene    TX    None
# 5     Abilene    TX    None
# 6   Ninilchik    AK    None
# 7     Lansing    MI    None
# 8    Stamford    CT    None
# 9   Champaign    IL    None
# 10    Atlanta    GA    None
# 11    Hialeah    Fl    None
# 12    Abilene    TX    None
# 13    Abilene    TX    None
# 14  Ninilchik    AK    None
# 15    Lansing    MI    None
# 16   Stamford    CT    None
# 17  Champaign    IL    None
# 18    Atlanta    GA    None
# 19    Hialeah    Fl    None
# 20    Abilene    TX    None
# 21    Abilene    TX    None
# 22  Ninilchik    AK    None
# 23    Lansing    MI    None
# 24   Stamford    CT    None
# 25  Champaign    IL    None
# 26    Atlanta    GA    None
# 27    Hialeah    Fl    None
# 28    Abilene    TX    None
# 29    Abilene    TX    None
# 30  Ninilchik    AK    None
# 31    Lansing    MI    None

# %% [markdown]
# ## Commit Your Changes to the Database
#
# Persist your changes by committing them to the database.

# %%
# Commit the changes to the database
conn.commit()

# %% [markdown]
# ## Create a Table for Student Grades
#
# Create a new table in the database called "grades". In the table, include the following fields: userId, courseId, grade.
#
# ** This problem is a bit more tricky and will require a dual key. (A nuance you have yet to see.)
# Here's how to do that:
#
# ```SQL
# CREATE TABLE table_name(
#    column_1 INTEGER NOT NULL,
#    column_2 INTEGER NOT NULL,
#    ...
#    PRIMARY KEY(column_1,column_2,...)
# );
# ```

# %%
# # Create a cursor object to execute SQL commands
# cursor = conn.cursor()

# Create the grades table
cursor.execute('''
    CREATE TABLE IF NOT EXISTS grades (
        userId INTEGER NOT NULL,
        courseId INTEGER NOT NULL,
        grade REAL,
        PRIMARY KEY (userId, courseId)
    )
''')

# # Commit the changes and close the cursor and connection
# conn.commit()
# cursor.close()
# conn.close()

# %% [markdown]
# ## Remove Duplicate Entries
#
# An analyst just realized that there is a duplicate entry in the contactInfo table! Find and remove it.

# %%
# Find the duplicate entries in the contactInfo table using a SQL query
query = '''
    SELECT firstName, lastName, telephone, COUNT(*) as count
    FROM contactInfo
    GROUP BY firstName, lastName, telephone
    HAVING count > 1
'''

# Execute the query and retrieve the duplicate entries as a DataFrame
duplicate_entries_df = pd.read_sql(query, conn)

# Print the duplicate entries
print(duplicate_entries_df)
# Out:
#      firstName  lastName telephone  count
# 0       Andrew     Stepp      None      4
# 1    Christine    Holden      None      4
# 2  Christopher    Warren      None      4
# 3           Ed     Lyman      None      4
# 4         Jane     Evans      None      8
# 5        Linda  Jacobson      None      4
# 6         Mary    Raines      None      4

# %%
# Remove the duplicate entries from the contactInfo table
for index, row in duplicate_entries_df.iterrows():
    firstName = row['firstName']
    lastName = row['lastName']
    telephone = row['telephone']
    count = row['count']

    cursor = conn.cursor()
    cursor.execute('''
        DELETE FROM contactInfo
        WHERE firstName = ? AND lastName = ? AND telephone = ?
        LIMIT ?
    ''', (firstName, lastName, telephone, count - 1))
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-13-36d56a93a0af> in <module>
#       7
#       8     cursor = conn.cursor()
# ----> 9     cursor.execute('''
#      10         DELETE FROM contactInfo
#      11         WHERE firstName = ? AND lastName = ? AND telephone = ?
#
# OperationalError: near "LIMIT": syntax error

# %%
# Check that the duplicate entry was removed

# %% [markdown]
# ## Updating an Address
#
# Ed Lyman just moved to `2910 Simpson Avenue York, PA 17403`. Update his address accordingly.

# %%
# Update Ed's address

# %%
# Query the database to ensure the change was made

# %% [markdown]
# ## Commit Your Changes to the Database
#
# Once again, persist your changes by committing them to the database.

# %%
# Your code here

# %% [markdown]
# ## Summary
#
# While there's certainly more to do with setting up and managing this database, you got a taste for creating, populating, and maintaining databases! Feel free to continue fleshing out this exercise for more practice.
